# %% [markdown]
# # Taller 2: Modelos de aprendizaje supervisado aplicado a la detección de diabetes

# %% [markdown]
# ## Introducción al trabajo

# %% [markdown]
# En la actualidad, la detección temprana de la diabetes mellitus representa un desafío crítico para la salud pública. Gracias al auge de las técnicas de aprendizaje automático, es posible construir modelos predictivos capaces de identificar con alta precisión a pacientes con riesgo de desarrollar esta enfermedad, lo cual facilita intervenciones médicas oportunas y mejora los resultados clínicos.
#
# Este proyecto de ciencia de datos se centra en la comparación de tres algoritmos de clasificación supervisada ampliamente utilizados:
#
# 1. **Regresión Logística**: Modelo lineal que estima la probabilidad de ocurrencia de un evento binario, ideal para problemas de diagnóstico donde la interpretabilidad de los coeficientes resulta clave.
# 2. **Árbol de Decisión**: Estructura jerárquica de reglas de decisión que particiona el espacio de atributos, ofreciendo interpretabilidad visual y manejo natural de interacciones no lineales.
# 3. **Bosque de Decisión (Random Forest)**: Ensamble de árboles de decisión que mejora la estabilidad y la precisión del modelo individual al promediar múltiples submodelos construidos sobre subconjuntos aleatorios de datos y variables.
#
# #### Descripción del Conjunto de Datos
#
# El dataset utilizado proviene del National Institute of Diabetes and Digestive and Kidney Diseases y está compuesto por pacientes femeninas nativas Pima de al menos 21 años. Contiene variables predictoras tales como:
#
# - Número de embarazos
# - Índice de Masa Corporal (BMI)
# - Nivel de insulina en suero
# - Edad
# - … y otras mediciones médicas relevantes
#
# La variable objetivo **Outcome** indica si el paciente presenta diabetes (1) o no (0).
# Cambiaremos el nombre de esta variable en la sección de EDA.

# %% [markdown]
# ## Objetivos del trabajo

# %% [markdown]
# - **Entrenar y validar** cada uno de los tres modelos (Regresión Logística, Árbol de Decisión, Random Forest) en un mismo pipeline de preprocesamiento.
# - **Comparar su desempeño** mediante métricas estándar de clasificación (accuracy, precisión, recall, F1-score y AUC-ROC).
# - **Analizar** la interpretabilidad de los modelos y su robustez ante variaciones en los datos (por ejemplo, a través de validación cruzada).

# %% [markdown]
# ## Estructura del Proyecto

# %% [markdown]
# 1. **Carga y preprocesamiento** de datos (imputación de valores faltantes, normalización, división train/test).
# 2. **Definición de pipelines** para cada algoritmo, incluyendo búsqueda de hiperparámetros (GridSearchCV).
# 3. **Evaluación de resultados** en test set y comparación de métricas.
# 4. **Discusión** sobre ventajas, limitaciones e implicaciones prácticas de cada modelo.

# %% [markdown]
# ## 0. Pits

# %%
# origen del visitante
entorno_trabajo = 'local'

# básicos de cocina
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# alistamiento de datos
from sklearn.model_selection import train_test_split
# modelos
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
# evaluación
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# optimizacion
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
# popurri
from sklearn.tree import export_graphviz
from IPython.display import Image
from io import StringIO
import pydotplus
from sklearn import tree
# remuestreo de datos
from imblearn.over_sampling import SMOTE
#--------------------------------------------------------
# existe un error en la convergencia de datos para el modelo de reg log
# es un dataset sintetico, por ende, error esperado
# desactivaremos este tipo de errores
import warnings
from sklearn.exceptions import ConvergenceWarning
#--------------------------------------------------------
# instalación de librerías faltantes
try:
    from six import StringIO
    import pydotplus
except:
    #Validar ejecución en consola!
    # %pip install graphviz pydotplus
    # %pip install six
    # %pip install pydotplus
    from six import StringIO
    import pydotplus

# %%
# Trataremos de mejorar el proceso de carga
def invocar_dataset(ds_path, entorno = entorno_trabajo):
    """Carga dataset a partir del entorno de trabajo.

    Args:
        ds_path (str): Ubicacion válida del archivo, URL o ubicación local.
        entorno (str, optional): Entorno de trabajo: local o colab. Defaults to entorno_trabajo.

    Returns:
        dataframe: Si la carga es correcta, devolverá el objeto de pandas dataframe.
    """
    # Swith
    if entorno == "colab":
        try:
            # Using google colab
            from google.colab import drive
            drive.mount('/content/drive')
            return pd.read_csv(ds_path)
        except:
        # if not...
            return pd.read_csv(ds_path)
    elif entorno == "local":
        return pd.read_csv(ds_path)
    else:
        print("No hay suficientes combinaciones")

# %% [markdown]
# ## 1. Carga y validación del dataset

# %% [markdown]
# Carga de un dataset. Se utiliza un bloque try-except para combinar uso de Google Drive/Conexión local.

# %%
pt_drive = "drive/MyDrive/data/diabetes.csv" # no tan util para ejecuciones compartidas
try:
    pt_local = "../datasets/diabetes.csv"
    df = invocar_dataset(pt_local)
except:
    # creo que esta es la mejor opción
    pt_git = (
    "https://raw.githubusercontent.com/ljpiere/class_notes/"
    "main/datasets/diabetes.csv"
    )
    df = invocar_dataset(pt_git)

# %% [markdown]
# Verificamos carga del dataset correcta.

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## 2. Exploración del dataframe

# %% [markdown]
# ### 2.1 Renombre de columnas

# %% [markdown]
# Algunas columnas tienen unos nombres algo extensos. Se renombra para más facilidad.

# %%
df.columns = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']

# %% [markdown]
# Validamos cambio.

# %%
df.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %% [markdown]
# ### 2.2 Verificación de valores nulos

# %% [markdown]
# Un loop nos ayudará a validar de primera mano la cantidad de vacíos en cada columna.

# %%
for i in df.columns:
  print("Column: ", i, "Null values: ", df[i].isnull().sum())
# Out:
# Column:  pregnant Null values:  0
# Column:  glucose Null values:  0
# Column:  bp Null values:  0
# Column:  skin Null values:  0
# Column:  insulin Null values:  0
# Column:  bmi Null values:  0
# Column:  pedigree Null values:  0
# Column:  age Null values:  0
# Column:  label Null values:  0

# %% [markdown]
# ### 2.3 Verificando balanceo de clases

# %% [markdown]
# La variable a predecir es la columna `label`. Esta indica `0` si el paciente no fue diagnosticado con diabetes y `1` si el paciente fue diagnosticado con diabetes.

# %%
df.groupby('label')['label'].count().plot(kind='bar', title='Conteo de clases')
# Out:
# <Axes: title={'center': 'Conteo de clases'}, xlabel='label'>

# %% [markdown]
# Las clases están desbalanceadas, esto es, tenemos más datos de la etiqueta `1` que de la etiqueta `0`. Esto significará un problema más adelante.

# %% [markdown]
# ### 2.4 Correlación de features

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Tenemos algunos puntos a resaltar de este análisis de correlación:
# - La edad, la glucosa y el bmi dan algunos indicios en la predicción.
# - No observamos correlaciones fuertes, tanto positivas como negativas.
# - Posiblemente nuestro modelo tome como "importantes" algunas features. Creemos que no serán todas importantes.

# %% [markdown]
# ## 3. Selección de features

# %% [markdown]
# Vamos a trabajar con solo un grupo de features para este ejercicio. Definiremos el conjunto X con las features utilizadas para predecir y el conjunto y solo con la etiqueta de diagnóstico.

# %%
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = df[feature_cols]
y = df.label

# %% [markdown]
# ## 4. Split de datos

# %% [markdown]
# Debemos delimitar los datos para entrenar y probar nuestro modelo.
#
# - Se deine un tamaño de conjunto de testeo `test` tomando el 25 % de los datos del conjunto global para `X` y `y`.
# - Creamos los conjuntos `train` y `test` a partir de ese porcentaje de división.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# %% [markdown]
# Fijamos el parámetro `random_state` como 16.

# %% [markdown]
# Por ahora.

# %% [markdown]
# ## 5. Busqueda del "mejor" modelo de Machine learning

# %% [markdown]
# ### Metodología propuesta

# %% [markdown]
# Se definirán distintos modelos. Buscamos un paso a paso "general" para cada modelo distinto. Para evitar caer en reprocesos, se propone la siguiente metodología:
#
# _Para cada modelo:_
# - **Punto de salida:** Un modelo benchmark básico sin optimizar que marcará el escenario básico a superar.
# - **Apuntar bien:** Buscaremos evaluar el accuaracy de nuestros modelos.
# - **Barajar:** Cada modelo se evaluará usando una busqueda por cuadrilla, donde se evaluarán distintas combinaciones de hiperparámetros. Incluiremos el `random_state`. _**Apunte:**_ Se manajerán listas de valores similares para hiperparámetros que los modelos compartan entre si.
# - **EL mejor de los mejores:** El modelo seleccionado deberá superar el modelo de benchmark.
# - **Aleatoriedad:** Buscaremos mantener semillas iguales o bien, generar diferentes modelos para diferentes semillas.

# %% [markdown]
# ### Recetario

# %% [markdown]
# Definiremos algunas funciones que nos permitirán hacer evaluaciones rápidas a partir de la reutilización de código.

# %%
def puesta_punto_modelo(model, X_train, X_test, y_train, y_test):
    """Entrenamiento, prediccion y evaluación del accuaracy para un
    modelo de clasificación.

    Args:
        model (sklearn): Modelo a entrenar, predecir y evaluar.
        X_train (list): Conjunto de features de entrenamiento.
        x_test (list): Conjunto de features de testeo.
        y_train (list): Conjunto de labels de entrenamiento.
        y_test (list): Conjunto de labels de testeo

    Returns:
        list: Predicciones, matriz de confuncion y accuaracy.
    """
    model_f = model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
    acc = metrics.accuracy_score(y_test, y_pred)
    
    return model_f, y_pred, cnf_matrix, acc

# %%
# nos será util más adelante...
def split_and_balance(X, y, 
                      test_size: float = 0.25, 
                      random_state: int = 16, 
                      sampler=SMOTE):
    """
    Divide X, y en train/test estratificado y luego remuestrea (oversample) 
    cada partición para que las clases queden balanceadas.
    
    Parámetros
    ----------
    X : DataFrame o array-like
        Variables predictoras.
    y : Series o array-like
        Vector objetivo binario.
    test_size : float
        Fracción de datos para test.
    random_state : int
        Semilla para reproducibilidad.
    sampler : clase de imblearn sampler
        Ej: SMOTE, RandomOverSampler, etc. 
        Debe aceptar (random_state) en su __init__.
    
    Retorna
    -------
    X_train_bal, X_test_bal, y_train_bal, y_test_bal
    """
    # 1) Split estratificado
    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=test_size,
        stratify=y,
        random_state=random_state
    )
    
    # 2) Inicializa y aplica sampler a cada partición
    sm = sampler(random_state=random_state)
    X_train_bal, y_train_bal = sm.fit_resample(X_train, y_train)
    X_test_bal,  y_test_bal  = sm.fit_resample(X_test,  y_test)
    
    return X_train_bal, X_test_bal, y_train_bal, y_test_bal

# %% [markdown]
# ### 5.1 Regresión logística

# %% [markdown]
# #### Benchmark

# %% [markdown]
# Generemos un modelo básico.

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=ConvergenceWarning)
    logreg_bch = LogisticRegression(random_state=16)
    logreg_bch, y_pred_logreg_bch, cnf_matrix_logreg_bch, acc_logreg_bch = puesta_punto_modelo(logreg_bch, X_train, X_test, y_train, y_test)

# %%
# calculo de su exactitud
acc_logreg_bch
# Out:
# 0.8177083333333334

# %%
class_names=[0,1] # name  of classes
tick_marks = np.arange(len(class_names))
# create heatmap
plt.figure(figsize=(4,2))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
sns.heatmap(pd.DataFrame(cnf_matrix_logreg_bch), annot=True, cmap="YlGnBu" ,fmt='g')
#ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# Nada mal para un primer modelo.

# %%
target_names = ['without diabetes', 'with diabetes']
print(classification_report(y_test, y_pred_logreg_bch, target_names=target_names))
# Out:
#                   precision    recall  f1-score   support
#
# without diabetes       0.82      0.93      0.87       125
#    with diabetes       0.82      0.61      0.70        67
#
#         accuracy                           0.82       192
#        macro avg       0.82      0.77      0.78       192
#     weighted avg       0.82      0.82      0.81       192

# %% [markdown]
# Recall cae frente a los pacientes con diabetes.

# %%
y_pred_proba = logreg_bch.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# En efecto, la curva ROC muestra que a nuestro modelo le cuesta identificar esos verdaderos positivos.

# %% [markdown]
# Revisemos como se comportan las semillas.

# %% [markdown]
# #### Optimización

# %%
param_grid = {'random_state': range(1, 42)}
grid = GridSearchCV(
        LogisticRegression(max_iter=2000, solver='saga'),  # saga o liblinear/sag
        param_grid=param_grid,
        cv=5,
        scoring='accuracy',
        n_jobs=-1
)

grid.fit(X_train, y_train)
print("Mejores hiperparámetros:", grid.best_params_)
print("Mejor accuracy CV:", grid.best_score_)
# Out:
# Mejores hiperparámetros: {'random_state': 1}
# Mejor accuracy CV: 0.6840329835082459
# C:\Users\ljpca\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# Buscar semillas no parece ser una opcion util, solo permite reproducibilidad. Obvio pero comprobado.

# %% [markdown]
# Usaremos como semilla el numero 37.

# %%
pipe = make_pipeline(
    StandardScaler(),
    LogisticRegression(max_iter=2000, random_state=37, solver='saga')
)

param_grid = {
    'logisticregression__C':      np.logspace(-3, 3, 7),   # fuerza de regularización
    'logisticregression__penalty':['l1', 'l2', 'elasticnet'],
    'logisticregression__l1_ratio': [0, .5, 1]             # solo se usa con elasticnet
}

grid = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid.fit(X_train, y_train)
print("Mejores hiperparámetros:", grid.best_params_)
print("Mejor accuracy CV:", grid.best_score_)
# Out:
# Mejores hiperparámetros: {'logisticregression__C': 1.0, 'logisticregression__l1_ratio': 0, 'logisticregression__penalty': 'l1'}
# Mejor accuracy CV: 0.7743928035982008
# C:\Users\ljpca\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1197: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(

# %%
with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=ConvergenceWarning)
    logreg_bch, y_pred_logreg_bch, cnf_matrix_logreg_bch, acc_logreg_bch = puesta_punto_modelo(grid, X_train, X_test, y_train, y_test)

target_names = ['without diabetes', 'with diabetes']
print(classification_report(y_test, y_pred_logreg_bch, target_names=target_names))
# Out:
#                   precision    recall  f1-score   support
#
# without diabetes       0.82      0.92      0.87       125
#    with diabetes       0.81      0.63      0.71        67
#
#         accuracy                           0.82       192
#        macro avg       0.81      0.77      0.79       192
#     weighted avg       0.82      0.82      0.81       192
# C:\Users\ljpca\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1197: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(

# %% [markdown]
# Mejoramos un poco nuestro modelo benchmark tomando en cuenta un ajuste más profundo de hiperparámetros para diferentes métricas. Mejoró mucho? En definitiva no. La convergencia de los datos dado este dataset sintetico no ayuda mucho. **Deberiamos revisar otros modelos.**

# %% [markdown]
# ### 5.2 Arbol de decisión

# %% [markdown]
# #### Benchmark

# %% [markdown]
# Iniciemos rápido con un arbol

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# looking for accuaracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7083333333333334

# %% [markdown]
# estamos lejos aun del modelo benchmark, quizás?

# %%
plt.figure(figsize=(6,4))
tree.plot_tree(clf,
               feature_names=feature_cols,
               class_names=['0','1'],
               filled=True,
               rounded=True)
plt.show()

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.765625

# %% [markdown]
# Mejoramos un poco.

# %%
plt.figure(figsize=(6,4))
tree.plot_tree(clf,
               feature_names=feature_cols,
               class_names=['0','1'],
               filled=True,
               rounded=True)
plt.show()

# %% [markdown]
# #### Optimización

# %% [markdown]
# Debemos podar este arbol. Ya encontramos que cambiar la semilla no ayuda pues mucho. Hagamos una busqueda en diferentes parámetros para encontrar la mejor combinación de hiperparámetros.

# %%
param_grid = {
    'criterion':    ['gini', 'entropy'],
    'max_depth':    list(range(1, 11)),
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf':  [1, 2, 4]
}

grid = GridSearchCV(
    estimator=DecisionTreeClassifier(),
    param_grid=param_grid,
    cv=5,
    scoring='roc_auc',   # 'roc_auc' -> AUC, accuaracy
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Mejores parámetros:", grid.best_params_)
print("Mejor accuracy CV:",  grid.best_score_)
# Out:
# Mejores parámetros: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Mejor accuracy CV: 0.7746463414634147

# %% [markdown]
# No mejora mucho, o quizás un 1 % pueda significar mucho. En cualquier caso existe n-combinaciones más de parámetros. Nos quedaremos con estas por ahora.

# %%
importances = clf.feature_importances_

# Crea un Series para ordenarlo y visualizarlo
fi = pd.Series(importances, index=X_train.columns)

# Ordénalo de mayor a menor y muéstralo
fi = fi.sort_values(ascending=False)
print(fi)
# Out:
# glucose     0.571035
# bmi         0.293506
# age         0.135459
# pregnant    0.000000
# insulin     0.000000
# bp          0.000000
# pedigree    0.000000
# dtype: float64

# %% [markdown]
# Al parecer algunas features no son tan relevantes, quizás podríamos...

# %%
fi.plot(kind='barh')
plt.xlabel('Importancia')
plt.title('Importancia de features en el árbol')
plt.gca().invert_yaxis()  # para que la más importante quede arriba
plt.show()

# %% [markdown]
# No usarlas? Igual el modelo no le está dando gran importancia a estas mismas.

# %%
#Predict the response for test dataset
y_pred = grid.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.765625

# %%
target_names = ['without diabetes', 'with diabetes']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                   precision    recall  f1-score   support
#
# without diabetes       0.79      0.88      0.83       125
#    with diabetes       0.71      0.55      0.62        67
#
#         accuracy                           0.77       192
#        macro avg       0.75      0.72      0.73       192
#     weighted avg       0.76      0.77      0.76       192

# %% [markdown]
# No parece ser mejor que nuestra regresión logística

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
class_names=[0,1] # name  of classes
tick_marks = np.arange(len(class_names))
# create heatmap
plt.figure(figsize=(4,2))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
#ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# Quizás el problemas de las clases desbalanceadas sea un punto a considerar.

# %% [markdown]
# ### 5.3 Bosque de decisión

# %% [markdown]
# #### Benchmark

# %% [markdown]
# Dos arboles piensan más que uno.

# %%
# 1. Define el modelo benchmark
rf_bench = RandomForestClassifier(
    n_estimators=100,      # número de árboles
    max_depth=None,        # profundidad máxima (None = hasta hoja pura)
    random_state=42,       # semilla para reproducibilidad
    n_jobs=-1              # usar todos los cores
)

# 2. Ajusta, predice y evalúa
rf_bench.fit(X_train, y_train)
y_pred_rf = rf_bench.predict(X_test)

# 3. Métricas clave
acc_rf    = metrics.accuracy_score(y_test, y_pred_rf)
cm_rf     = metrics.confusion_matrix(y_test, y_pred_rf)
roc_auc_rf = metrics.roc_auc_score(y_test, rf_bench.predict_proba(X_test)[:,1])

print(f"Accuracy RF:    {acc_rf:.4f}")
print(f"ROC AUC RF:     {roc_auc_rf:.4f}")
print("Matriz de confusión:")
# Out:
# Accuracy RF:    0.8021
# ROC AUC RF:     0.8798
# Matriz de confusión:

# %%
target_names = ['without diabetes', 'with diabetes']
print(classification_report(y_test, y_pred_rf, target_names=target_names))
# Out:
#                   precision    recall  f1-score   support
#
# without diabetes       0.81      0.90      0.86       125
#    with diabetes       0.77      0.61      0.68        67
#
#         accuracy                           0.80       192
#        macro avg       0.79      0.76      0.77       192
#     weighted avg       0.80      0.80      0.80       192

# %% [markdown]
# Mismos problemas. Quizás.

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
class_names=[0,1] # name  of classes
tick_marks = np.arange(len(class_names))
# create heatmap
plt.figure(figsize=(4,2))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
sns.heatmap(pd.DataFrame(cm_rf), annot=True, cmap="YlGnBu" ,fmt='g')
#ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# Busquemos una mejor combinación:

# %% [markdown]
# #### Optimización

# %%
# Modelo base a optimizar
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# No usaremos muchos
# El tiempo de ejcución TARDA!
param_grid = {
    'n_estimators':      [50, 100, 200],   # número de árboles en el bosque
    'max_depth':         [None, 10, 20, 30],  # profundidad máxima de cada árbol
    'min_samples_split': [2, 5, 10],  # min. muestras para dividir un nodo
    'min_samples_leaf':  [1, 2, 4],  # min. muestras en una hoja
    'max_features':      ['sqrt', 'log2', None] # número de features consideradas en cada split
}

# configuremos nuestra matriz de posibilidades
grid_rf = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,       # 5-fold cross-validation
    scoring='accuracy',   # puedes usar 'roc_auc' si prefieres AUC
    n_jobs=-1,  # usar todos los cores
    verbose=1       # ver progreso
)

# entrenamos!
grid_rf.fit(X_train, y_train)

# revisemos
print("Mejores hiperparámetros:", grid_rf.best_params_)
print(f"Mejor accuracy CV: {grid_rf.best_score_:.4f}")

# seleccionemos el mejor estimador!
best_rf = grid_rf.best_estimator_
y_pred = best_rf.predict(X_test)

from sklearn import metrics
print(f"Accuracy en test: {metrics.accuracy_score(y_test, y_pred):.4f}")
print(f"ROC AUC en test:  {metrics.roc_auc_score(y_test, best_rf.predict_proba(X_test)[:,1]):.4f}")
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Mejores hiperparámetros: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Mejor accuracy CV: 0.7553
# Accuracy en test: 0.7969
# ROC AUC en test:  0.8812

# %% [markdown]
# Realmente estamos "sacrificando" verdaderos positivos. El modelo sigue algo confuso.

# %%
print("Matriz de confusión:\n", metrics.confusion_matrix(y_test, y_pred))
# Out:
# Matriz de confusión:
#  [[114  11]
#  [ 28  39]]

# %% [markdown]
# ## 6. Balanceo de clases

# %% [markdown]
# #### Un pequeño ajuste

# %% [markdown]
# Balanceemos los clases y revisemos como se comportan nuestros modelos.

# %%
feature_cols = ['pregnant','insulin','bmi','age','glucose','bp','pedigree']
X = df[feature_cols]
y = df.label

# obtengo train/test balanceados
X_train, X_test, y_train, y_test = split_and_balance(X, y, test_size=0.25)

# %% [markdown]
# ### 6.1 Regresión logística

# %% [markdown]
# Probaremos ahora los siguientes ajuste en nuestro modelo de regresión logística:
# - Penalidad l1 y l2 para mejorar ajuste
# - Las clases ya están balanceadas, ajustaremos el solver como linear

# %%
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear']
}

# GridSearchCV con múltiples métricas
grid = GridSearchCV(
    LogisticRegression(random_state=16),
    param_grid,
    cv=5,
    scoring=['accuracy','precision','recall','f1'],
    refit='accuracy',
    n_jobs=-1,
    return_train_score=False
)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=16), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100], 'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear']},
#              refit='accuracy',
#              scoring=['accuracy', 'precision', 'recall', 'f1'])

# %% [markdown]
# Probaremos generando nuestro conjuntos de datos balanceados en diferentes random states.

# %%
random_states = [0, 16, 42, 100, 2025] # definiremos solo un par de seeds
accuracies = []

# Entrena y evalúa para cada seed
for rs in random_states:
    X_tr, X_te, y_tr, y_te = split_and_balance(X, y, test_size=0.25, random_state=rs)
    clf = LogisticRegression(random_state=rs, solver='liblinear')
    clf.fit(X_tr, y_tr)
    accuracies.append(clf.score(X_te, y_te))

# grafica sencilla
plt.figure()
plt.plot(random_states, accuracies, marker='o')
plt.xlabel('Random State')
plt.ylabel('Test Set Accuracy')
plt.title('Impacto de cambio semilla en la precisión')
plt.grid(True)
# plt.tight_layout()
plt.show()

# %% [markdown]
# bueno, creo que no hay que exagerar en las semillas que escogemos.

# %%
# guardemos los resultados
results = pd.DataFrame(grid.cv_results_)

# %%
plt.figure(figsize=(8,5))
metrics = ['accuracy','precision','recall','f1']
for pen in param_grid['penalty']:
    subset = results[results['param_penalty']==pen]
    for m in metrics:
        plt.plot(subset['param_C'], subset[f'mean_test_{m}'],
                 marker='o', label=f'{m.capitalize()} (penalty={pen})')

plt.xscale('log')
plt.xlabel('C (inverse regularization strength)')
plt.ylabel('Mean CV score')
plt.title('Grid Search Logistic Regression\nCV Accuracy / Precision / Recall / F1')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Tenemos diferentes combinaciones, logramos, frente al modelo de benchmark, mejorar nuestro f1-score y recall significativamente para los pacientes con diabetes

# %%
best = grid.best_estimator_
y_pred = best.predict(X_test)
print("Mejores hiperparámetros:", grid.best_params_)
print("\nReporte en Test Set:\n")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Mejores hiperparámetros: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
#
# Reporte en Test Set:
#
#               precision    recall  f1-score   support
#
#            0     0.8000    0.7680    0.7837       125
#            1     0.7769    0.8080    0.7922       125
#
#     accuracy                         0.7880       250
#    macro avg     0.7885    0.7880    0.7879       250
# weighted avg     0.7885    0.7880    0.7879       250

# %% [markdown]
# Nuestro modelo es, muy bueno frente al primero generado.

# %% [markdown]
# ### 6.2 Arbol de decisión

# %% [markdown]
# Probaremos ahora un arbol de decisión.

# %% [markdown]
# Usemos distintas combinaciones de semillas.

# %%
random_states = [0, 16, 42, 100, 2025]
accuracies = []

for rs in random_states:
    X_tr, X_te, y_tr, y_te = split_and_balance(X, y, test_size=0.25, random_state=rs)
    dt = DecisionTreeClassifier(random_state=rs)
    dt.fit(X_tr, y_tr)
    accuracies.append(dt.score(X_te, y_te))

# %%
plt.figure()
plt.plot(random_states, accuracies, marker='o')
plt.xlabel('Random State')
plt.ylabel('Test Set Accuracy')
plt.title('Decision Tree: Impacto de random_state en la precisión')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Llegamos a la misma conclusion, no debemos de exagerar con las semillas.

# %% [markdown]
# Probemos ahora optimizar los hiperparémtros de nuestro modelo.

# %%
param_grid = {
    'max_depth': [2, 4, 6, 8, 10, None], # mejor no exagerar
    'criterion': ['gini', 'entropy']
}

# selecciones algunas metricas básicas para evaluar
scoring = {'acc':'accuracy','prec':'precision','recall':'recall','f1':'f1'}

# %%
grid = GridSearchCV(
    DecisionTreeClassifier(random_state=16),
    param_grid,
    cv=5,
    scoring=scoring,
    refit='acc',
    n_jobs=-1
)
grid.fit(X_train, y_train)
results = pd.DataFrame(grid.cv_results_)

# la anterior ejecución tardo mucho, no exageraremos en la busqueda por cuadricula
numeric_depths = [d for d in param_grid['max_depth'] if isinstance(d, int)]
none_plot = max(numeric_depths) + 2

# %% [markdown]
# Ahora revisemos el comportamiento

# %%
plt.figure(figsize=(8,5))
metrics = ['acc','prec','recall','f1']

for crit in param_grid['criterion']:
    sub = results[results['param_criterion']==crit]
    depths = sub['param_max_depth'].apply(lambda d: d if d is not None else none_plot)
    for m in metrics:
        plt.plot(
            depths,
            sub[f'mean_test_{m}'],
            marker='o',
            label=f'{m.upper()} (crit={crit})'  # <-- aquí defines la etiqueta
        )

plt.xlabel(f'max_depth (None→{none_plot})')
plt.ylabel('Mean CV score')
plt.title('Decision Tree: Grid Search')
plt.legend(loc='best')  # <-- legend() tras todos los plot()
plt.tight_layout()
plt.show()

# %% [markdown]
# No hay necesidad de buscarlo a ojo.

# %%
best = grid.best_estimator_
y_pred = best.predict(X_test)
print("Mejores hiperparámetros:", grid.best_params_)
print("\nReporte en Test Set:\n")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Mejores hiperparámetros: {'criterion': 'entropy', 'max_depth': 10}
#
# Reporte en Test Set:
#
#               precision    recall  f1-score   support
#
#            0     0.6619    0.7360    0.6970       125
#            1     0.7027    0.6240    0.6610       125
#
#     accuracy                         0.6800       250
#    macro avg     0.6823    0.6800    0.6790       250
# weighted avg     0.6823    0.6800    0.6790       250

# %% [markdown]
# Bueno, esto es decepcionante.

# %% [markdown]
# El modelo no es precisamente el mejor, aunque el f1-score es similar para ambas clases, no es un ajuste sorprente, Al menos no el que esperabamos. La precision no es la mejor igual. Nuestro modelo, muy pobremente, logra diferenciar bien las etiquetas a predecir.

# %% [markdown]
# ### 6.3 Bosque clasificador

# %% [markdown]
# Esperemos que el bosque sea mejor, quizás.

# %%
param_grid = {
    'n_estimators': [50, 100, 200], # la ejecución puede tardr algo, bajemos estos estimadores
    'max_depth': [None, 5, 10],
}
scoring = {'acc':'accuracy','prec':'precision','recall':'recall','f1':'f1'}

# %%
grid = GridSearchCV(
    RandomForestClassifier(random_state=16),
    param_grid,
    cv=5,
    scoring=scoring,
    refit='acc',
    n_jobs=-1,
    return_train_score=False
)
grid.fit(X_train, y_train)
results = pd.DataFrame(grid.cv_results_)

# %%
depths_numeric = [d for d in param_grid['max_depth'] if isinstance(d, int)]
none_plot = max(depths_numeric) + 2

# %%
plt.figure(figsize=(8,5))
metrics = ['acc','prec','recall','f1']
for depth in param_grid['max_depth']:
    sub = results[results['param_max_depth'] == depth]
    # mapear None a valor numérico
    label_depth = 'None' if depth is None else str(depth)
    for m in metrics:
        plt.plot(
            sub['param_n_estimators'],
            sub[f'mean_test_{m}'],
            marker='o',
            label=f'{m.upper()} (max_depth={label_depth})'
        )

plt.xlabel('n_estimators')
plt.ylabel('Mean CV score')
plt.title('Grid Search Random Forest\nAccuracy / Precision / Recall / F1')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# Buen augurio.

# %% [markdown]
# Los diferentes modelos generados suelen responder de formar mas "drastica" a los cambios en los hiperparámetros. Quizás tengamos mejor suerte que con un simple arbol.

# %%
random_states = [0, 16, 42, 100, 2025]
accuracies = []

for rs in random_states:
    X_tr, X_te, y_tr, y_te = split_and_balance(X, y, test_size=0.25, random_state=rs)
    rf = RandomForestClassifier(random_state=rs, n_estimators=100)
    rf.fit(X_tr, y_tr)
    accuracies.append(rf.score(X_te, y_te))

# %% [markdown]
# Veamos los cambios en la semilla que genera los conjuntos de datos.

# %%
plt.figure()
plt.plot(random_states, accuracies, marker='o')
plt.xlabel('Random State')
plt.ylabel('Test Set Accuracy')
plt.title('Random Forest: Impacto de random_state en la precisión')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Misma conclusión de las anteriores.

# %% [markdown]
# Busquemos nuestro mejor modelo.

# %%
best = grid.best_estimator_
y_pred = best.predict(X_test)
print("Mejores hiperparámetros:", grid.best_params_)
print("\nReporte en Test Set:\n")
print(classification_report(y_test, y_pred, digits=4))
# Out:
# Mejores hiperparámetros: {'max_depth': None, 'n_estimators': 50}
#
# Reporte en Test Set:
#
#               precision    recall  f1-score   support
#
#            0     0.7462    0.7760    0.7608       125
#            1     0.7667    0.7360    0.7510       125
#
#     accuracy                         0.7560       250
#    macro avg     0.7564    0.7560    0.7559       250
# weighted avg     0.7564    0.7560    0.7559       250

# %% [markdown]
# Mejoramos considerablemente frente al arbol.

# %% [markdown]
# **Tala indiscriminada:** Quizás pudimos probar más combinaciones en la busqueda por cuadrilla. Al menos estos resultados tenian un mejor comportamiento y en el gráfico de evaluación de métricas veiamos que el modelo respondía bien frente a las modificaciones de estos hiperparámetros. SOlo que la busqueda estaba ya tomando mucho tiempo.
#
# **Ampliar horizontes:** Ajustar los parámetros del GridSearch nos podría ayudar a buscar un mejor modelo.

# %% [markdown]
# ### 6. Comparación

# %% [markdown]
# Revisemos un resumen de nuestros modelos. De forma básica.

# %%
# Un pequeño error: No guardar mejor estas métricas 
# regresion logistica: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# arbol: {'criterion': 'entropy', 'max_depth': 10}
# bosque: {'max_depth': None, 'n_estimators': 50}

# Creemos nuestros "super modelos"
models = {
    'Logistic Regression': LogisticRegression(random_state=16, C=10, penalty='l1', solver='liblinear'),
    'Decision Tree': DecisionTreeClassifier(random_state=16, criterion='entropy', max_depth=10),
    'Random Forest': RandomForestClassifier(random_state=16, n_estimators=50, max_depth= None)
}

# algunas métricas
metrics = ['Accuracy', 'Precision', 'Recall', 'F1']
results = {model_name: {} for model_name in models}

for name, clf in models.items():
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    results[name]['Accuracy'] = accuracy_score(y_test, y_pred)
    results[name]['Precision'] = precision_score(y_test, y_pred)
    results[name]['Recall'] = recall_score(y_test, y_pred)
    results[name]['F1'] = f1_score(y_test, y_pred)

df_results = pd.DataFrame(results).T  


x = np.arange(len(models)) 
width = 0.2
plt.figure(figsize=(8,5))
for idx, metric in enumerate(metrics):
    plt.bar(x + idx*width, df_results[metric], width, label=metric)
plt.xlabel('Modelos')
plt.ylabel('Valor de Métrica')
plt.title('Comparación de Métricas por Modelo')
plt.xticks(x + width*1.5, df_results.index, rotation=45)
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# La función de activación de la regresión logística parece dividir nuestras predicciones de mejor forma. No le quitemos protagonismo al bosque, pudo haberse ampliado la busqueda de parámetros. El arbol de decisión como principal decepción.

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# 1. **Regresión Logística**
#    - **Mejor rendimiento global**: obtuvo la mayor _accuracy_ (0.78), _precision_ (0.78), _recall_ (0.79) y _F1_ (0.79).
#    - **Interpretabilidad**: sus coeficientes permiten comprender fácilmente la contribución de cada variable al diagnóstico.
#    - **Recomendación**: modelo ideal si se prioriza la simplicidad y la transparencia.
#
# 2. **Árbol de Decisión**
#    - **Peor desempeño**: _accuracy_ (0.71), _precision_ (0.73), _recall_ (0.66) y _F1_ (0.70), mostrando tendencia al sobreajuste o a particionar en profundidad insuficiente según los hiperparámetros por defecto.
#    - **Ventaja**: reglas de decisión muy intuitivas, aunque la estabilidad y la generalización quedan por debajo de los otros dos.
#    - **Recomendación**: puede servir para una primera exploración de patrones, pero requiere ajuste fino de `max_depth`, `min_samples_leaf`, etc.
#
# 3. **Random Forest**
#    - **Rendimiento intermedio**: _accuracy_ (0.75), _precision_ (0.76), _recall_ (0.75) y _F1_ (0.75).
#    - **Robustez**: al combinar múltiples árboles reduce la varianza del árbol individual y mejora la estabilidad en datos desequilibrados.
#    - **Recomendación**: buena opción cuando se busca un balance entre precisión y generalización, con tolerancia a menor interpretabilidad.
